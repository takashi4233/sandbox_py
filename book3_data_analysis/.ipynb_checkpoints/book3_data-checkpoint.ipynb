# %%
import pandas as pd

# %%
df = pd.DataFrame({"NAME":["Alice","Bob","Charly","Eve","Frank"],"AGE":[10,20,30,20,10]})

# %%
df["ADDRESS"] = ["TOKYO","OSAKA","TOKYO","OSAKA","AICHI"]

# %%
df["COMPANY_PLACE"] = ["TOKYO","TOKYO","AICHI","OSAKA","OSAKA"]

# %%
df.head()
# Out:
#      NAME  AGE ADDRESS COMPANY_PLACE
# 0   Alice   10   TOKYO         TOKYO
# 1     Bob   20   OSAKA         TOKYO
# 2  Charly   30   TOKYO         AICHI
# 3     Eve   20   OSAKA         OSAKA
# 4   Frank   10   AICHI         OSAKA

# %%
df = df.drop("ALL_INFO",axis=1)

# %%
df.head()
# Out:
#      NAME  AGE ADDRESS COMPANY_PLACE
# 0   Alice   10   TOKYO         TOKYO
# 1     Bob   20   OSAKA         TOKYO
# 2  Charly   30   TOKYO         AICHI
# 3     Eve   20   OSAKA         OSAKA
# 4   Frank   10   AICHI         OSAKA

# %%
df.loc[:,"ALL_INFO2"] = f"{df.loc[:,'NAME']}|{df.loc[:,'AGE']}|{df.loc[:,'ADDRESS']}|{df.loc[:,'COMPANY_PLACE']}"
df
# Out:
#      NAME  AGE ADDRESS COMPANY_PLACE  \
# 0   Alice   10   TOKYO         TOKYO
# 1     Bob   20   OSAKA         TOKYO
# 2  Charly   30   TOKYO         AICHI
# 3     Eve   20   OSAKA         OSAKA
# 4   Frank   10   AICHI         OSAKA
#
#                                            ALL_INFO2
# 0  0     Alice\n1       Bob\n2    Charly\n3      ...
# 1  0     Alice\n1       Bob\n2    Charly\n3      ...
# 2  0     Alice\n1       Bob\n2    Charly\n3      ...
# 3  0     Alice\n1       Bob\n2    Charly\n3      ...
# 4  0     Alice\n1       Bob\n2    Charly\n3      ...

# %%
df
# Out:
#      NAME  AGE ADDRESS COMPANY_PLACE  \
# 0   Alice   10   TOKYO         TOKYO
# 1     Bob   20   OSAKA         TOKYO
# 2  Charly   30   TOKYO         AICHI
# 3     Eve   20   OSAKA         OSAKA
# 4   Frank   10   AICHI         OSAKA
#
#                                             ALL_INFO
# 0  {df['NAME']}|{df['AGE']}|{df['ADDRESS']}|{df['...
# 1  {df['NAME']}|{df['AGE']}|{df['ADDRESS']}|{df['...
# 2  {df['NAME']}|{df['AGE']}|{df['ADDRESS']}|{df['...
# 3  {df['NAME']}|{df['AGE']}|{df['ADDRESS']}|{df['...
# 4  {df['NAME']}|{df['AGE']}|{df['ADDRESS']}|{df['...
