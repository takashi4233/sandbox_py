# %%
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series,DataFrame

#
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

# %precision 3
# Out:
# '%.3f'

# %%
x = [1,2,3]
y = [10,1,4]

plt.figure(figsize = (10,6))
plt.subplot(1,2,1)
plt.bar(x,y,align='center',width=0.5)
plt.xticks(x,['A Class','B Class','C Class'])
plt.xlabel('Class')
plt.ylabel('Score')



plt.subplot(1,2,2)
plt.bar(x,y,width=0.5)
plt.xticks(x,['A Class','B Class','C Class'])

plt.xlabel('Class')
plt.ylabel('Score')

plt.grid(True)

# %%
x = [1,2,3]
y = [10,1,4]

plt.figure(figsize = (10,6))
plt.barh(x,y,align='center')
plt.yticks(x,['A Class','B Class','C Class'])
plt.xlabel('Score')
plt.ylabel('Class')
plt.grid(True)

# %%
y1 = np.array([30,10,40])
y2 = np.array([10,50,90])

x = np.arange(len(y1))

w = 0.4

plt.figure(figsize=(10,6))
plt.bar(x,y1,color='blue',width=w,label = 'Math first',align='center')
plt.bar(x +w,y2,color='green',width = w,label ='Math final',align='center')

plt.legend(loc='best')

plt.xticks(x + w/2,['Class A','Class B','Class C'])
plt.grid(True)

# %%
height1 = np.array([100,200,300,400,500])
height2 = np.array([1000,800,600,400,200])

x = np.array([1,2,3,4,5])

plt.figure(figsize = (10,6))
p1 = plt.bar(x,height1,color='blue')
p2 = plt.bar(x,height2,bottom=height1,color='lightblue')

plt.legend((p1[0],p2[0]),('Class a','Class B'))

# %%
height1 = np.array([100,200,300,400,500])
height2 = np.array([1000,800,600,400,200])
height3 = np.array([500,600,700,800,900])

x = np.array([1,2,3,4,5])

w = 0.4

plt.figure(figsize = (10,6))
p1 = plt.bar(x,height1,width = w,color='blue')
p2 = plt.bar(x,height2,width = w,bottom=height1,color='lightblue')
p3 = plt.bar(x + w,height3,width = w,color= 'lightgreen')

plt.xticks(x + w/2)


plt.legend((p1[0],p2[0]),('Class a','Class B'))

# %%
labels = ['Frogs','Hogs','Dogs','Logs']
sizes = [25,30,55,10]
colors = ['yellowgreen','gold','lightskyblue','lightcoral']
explode = (0,0.1,0,0,)

plt.figure(figsize = (15,6))
plt.pie(sizes,explode=explode,labels = labels,colors = colors,
        autopct = '%1.1f%%',shadow = True,startangle = 90,counterclock=False)

plt.axis ('equal')
# Out:
# (-1.1321948854058426,
#  1.228447025710862,
#  -1.130135568274971,
#  1.1014350313465868)

# %%
N = 25
x = np.random.rand(N)
y = np.random.rand(N)

colors = np.random.rand(N)

area = 10 * np.pi * (15 *np.random.rand(N)) ** 2

plt.figure(figsize = (15,6))

plt.scatter(x,y,s = area,c = colors,alpha = 0.5)
plt.grid(True)

# %%
pd_student = pd.read_csv('student-mat.csv',sep=';')
colors = ['yellowgreen','gold','lightskyblue','lightcoral']


pd_student['reason'].value_counts().plot(kind='pie',figsize=(10,10),
                                         startangle = 90,colors = colors,counterclock=False,autopct = '%1.1f%%'
                                        ,legend ='best' )

# %%
plt.subplot(1,2,1)
pd_student.groupby('higher')['G1'].mean().plot(kind='bar')
plt.subplot(1,2,2)
pd_student.groupby('higher')['G3'].mean().plot(kind='bar')

# %%
pd_student.groupby('traveltime')['G3'].mean().plot(kind='barh')

# %%
idx = pd.date_range('2015/01/01','2015/12/31 23:59',freq='T')
dn = np.random.randint(2,size=len(idx))* 2 -1
rnd_walk = np.cumprod(np.exp(dn * 0.0002)) * 100
df = pd.Series(rnd_walk,index=idx).resample('B').ohlc()
df.plot(figsize=(15,6),legend='best',grid=True)

# %%
from plotly.offline import init_notebook_mode,iplot
from plotly import figure_factory as FF

init_notebook_mode(connected = True)
fig = FF.create_candlestick(df.open,df.high,df.low,df.close,dates=df.index)
iplot(fig)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="67ab64f0-58bd-4126-856b-c8b721ab22bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("67ab64f0-58bd-4126-856b-c8b721ab22bf")) {
#                     Plotly.newPlot(
# ...

# %%
cd chapter7
# Out:
# [Errno 2] No such file or directory: 'chapter7'
# /Users/takashi/takashi/sandbox/python/book1/chapter7

# %%
pd_chp7 = pd.read_csv('dow_jones_index.data')
pd_chp7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 16 columns):
# quarter                               750 non-null int64
# stock                                 750 non-null object
# date                                  750 non-null object
# open                                  750 non-null object
# high                                  750 non-null object
# low                                   750 non-null object
# close                                 750 non-null object
# volume                                750 non-null int64
# percent_change_price                  750 non-null float64
# percent_change_volume_over_last_wk    720 non-null float64
# previous_weeks_volume                 720 non-null float64
# next_weeks_open                       750 non-null object
# next_weeks_close                      750 non-null object
# percent_change_next_weeks_price       750 non-null float64
# ...

# %%
pd_chp7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 16 columns):
# quarter                               750 non-null int64
# stock                                 750 non-null object
# date                                  750 non-null object
# open                                  750 non-null object
# high                                  750 non-null object
# low                                   750 non-null object
# close                                 750 non-null object
# volume                                750 non-null int64
# percent_change_price                  750 non-null float64
# percent_change_volume_over_last_wk    720 non-null float64
# previous_weeks_volume                 720 non-null float64
# next_weeks_open                       750 non-null object
# next_weeks_close                      750 non-null object
# percent_change_next_weeks_price       750 non-null float64
# ...

# %%
pd_chp7.date = pd.to_datetime(pd_chp7.date)
pd_chp7.open = pd.to_numeric(pd_chp7.open.map(lambda x:str(x).replace('$','')))
pd_chp7.close = pd.to_numeric(pd_chp7.close.map(lambda x:str(x).replace('$','')))
pd_chp7.high = pd.to_numeric(pd_chp7.high.map(lambda x:str(x).replace('$','')))
pd_chp7.low = pd.to_numeric(pd_chp7.low.map(lambda x:str(x).replace('$','')))
pd_chp7.next_weeks_open = pd.to_numeric(pd_chp7.next_weeks_open.map(lambda x:str(x).replace('$','')))
pd_chp7.next_weeks_close = pd.to_numeric(pd_chp7.next_weeks_close.map(lambda x:str(x).replace('$','')))

# %%
pd_chp7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 16 columns):
# quarter                               750 non-null int64
# stock                                 750 non-null object
# date                                  750 non-null datetime64[ns]
# open                                  750 non-null float64
# high                                  750 non-null float64
# low                                   750 non-null float64
# close                                 750 non-null float64
# volume                                750 non-null int64
# percent_change_price                  750 non-null float64
# percent_change_volume_over_last_wk    720 non-null float64
# previous_weeks_volume                 720 non-null float64
# next_weeks_open                       750 non-null float64
# next_weeks_close                      750 non-null float64
# percent_change_next_weeks_price       750 non-null float64
# ...

# %%
pd_chp7.head()
# Out:
#    quarter stock       date    open    high     low   close     volume  \
# 0        1    AA   1/7/2011  $15.82  $16.72  $15.78  $16.42  239655616
# 1        1    AA  1/14/2011  $16.71  $16.71  $15.64  $15.97  242963398
# 2        1    AA  1/21/2011  $16.19  $16.38  $15.60  $15.79  138428495
# 3        1    AA  1/28/2011  $15.87  $16.63  $15.82  $16.13  151379173
# 4        1    AA   2/4/2011  $16.18  $17.39  $16.18  $17.14  154387761
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0               3.79267                                 NaN
# 1              -4.42849                            1.380223
# 2              -2.47066                          -43.024959
# 3               1.63831                            9.355500
# 4               5.93325                            1.987452
#
#    previous_weeks_volume next_weeks_open next_weeks_close  \
# 0                    NaN          $16.71           $15.97
# ...

# %%
def func(x):
    return str(x).replace('$','')

# %%
pd_chp7 = pd.read_csv('dow_jones_index.data')
pd_chp7.close = pd.to_numeric(pd_chp7.close.map(func))

# %%
del_dol =  lambda x: str(x).replace('$','')

# %%
pd_chp7.open = pd.to_numeric(pd_chp7.open.map(del_dol))
pd_chp7.open = pd.to_numeric(pd_chp7.open.map(del_dol))
pd_chp7.close = pd.to_numeric(pd_chp7.close.map(del_dol))
pd_chp7.high = pd.to_numeric(pd_chp7.high.map(del_dol))
pd_chp7.low = pd.to_numeric(pd_chp7.low.map(del_dol))
pd_chp7.next_weeks_open = pd.to_numeric(pd_chp7.next_weeks_open.map(del_dol))
pd_chp7.next_weeks_close = pd.to_numeric(pd_chp7.next_weeks_close.map(del_dol))

# %%
pd_chp7.head()
# Out:
#    quarter stock       date   open   high    low  close     volume  \
# 0        1    AA   1/7/2011  15.82  16.72  15.78  16.42  239655616
# 1        1    AA  1/14/2011  16.71  16.71  15.64  15.97  242963398
# 2        1    AA  1/21/2011  16.19  16.38  15.60  15.79  138428495
# 3        1    AA  1/28/2011  15.87  16.63  15.82  16.13  151379173
# 4        1    AA   2/4/2011  16.18  17.39  16.18  17.14  154387761
#
#    percent_change_price  percent_change_volume_over_last_wk  \
# 0               3.79267                                 NaN
# 1              -4.42849                            1.380223
# 2              -2.47066                          -43.024959
# 3               1.63831                            9.355500
# 4               5.93325                            1.987452
#
#    previous_weeks_volume  next_weeks_open  next_weeks_close  \
# 0                    NaN            16.71             15.97
# 1            239655616.0            16.19             15.79
# ...

# %%
pd_chp7.groupby('stock')['close'].describe()
pd_chp7_idx = pd_chp7.set_index(['date','stock'])
pd_chp7_idx_uns = pd_chp7_idx.unstack()['close']
pd_chp7_idx_uns.describe()
# Out:
# stock         AA        AXP         BA        BAC         CAT       CSCO  \
# count  25.000000  25.000000  25.000000  25.000000   25.000000  25.000000
# mean   16.504400  46.712400  73.448000  13.051600  103.152000  17.899200
# std     0.772922   2.396248   3.087631   1.417382    6.218651   1.984095
# min    14.720000  43.530000  69.100000  10.520000   92.750000  14.930000
# 25%    16.030000  44.360000  71.640000  11.930000   99.590000  16.880000
# 50%    16.520000  46.250000  72.690000  13.370000  103.540000  17.520000
# 75%    17.100000  48.500000  74.840000  14.250000  107.210000  18.700000
# max    17.920000  51.190000  79.780000  15.250000  115.410000  22.050000
#
# stock         CVX         DD        DIS         GE  ...        MRK       MSFT  \
# count   25.000000  25.000000  25.000000  25.000000  ...  25.000000  25.000000
# mean   101.175600  52.873600  41.249600  19.784000  ...  34.360400  25.920800
# ...

# %%
pd_chp7_idx_uns
# Out:
# stock         AA    AXP     BA    BAC     CAT   CSCO     CVX     DD    DIS  \
# date
# 1/14/2011  15.97  46.25  70.07  15.25   94.01  21.21   92.83  49.80  39.29
# 1/21/2011  15.79  46.00  71.68  14.25   92.75  20.72   93.78  48.35  39.74
# 1/28/2011  16.13  43.86  69.23  13.60   95.68  20.93   93.37  50.29  38.85
# 1/7/2011   16.42  44.36  69.38  14.25   93.73  20.97   91.19  49.76  39.45
# 2/11/2011  17.37  46.75  72.14  14.77  103.54  18.70   96.45  54.58  43.41
# 2/18/2011  17.28  45.53  73.04  14.75  105.86  18.85   98.72  55.98  43.56
# 2/25/2011  16.68  43.53  72.30  14.20  102.00  18.64  102.10  54.07  42.95
# 2/4/2011   17.14  43.82  71.38  14.29   99.59  22.05   97.11  52.53  40.71
# 3/11/2011  16.03  44.28  71.64  14.38  100.02  17.95   99.93  52.90  42.93
# 3/18/2011  16.11  44.17  69.10  14.04  105.06  17.14  102.80  52.99  41.23
# 3/25/2011  17.09  45.59  73.34  13.34  109.09  17.28  106.78  54.10  42.97
# ...

# %%
corr_data = pd_chp7_idx_uns.corr()
corr_data[0:2]
# Out:
# stock        AA       AXP        BA       BAC       CAT      CSCO       CVX  \
# stock
# AA     1.000000 -0.132094  0.291520  0.432240  0.695727  0.277191  0.470529
# AXP   -0.132094  1.000000  0.792575 -0.746595  0.255515 -0.593743  0.236456
#
# stock        DD       DIS        GE  ...       MRK      MSFT       PFE  \
# stock                                ...
# AA     0.762246  0.772470  0.740139  ... -0.194258  0.317951  0.111613
# AXP    0.004094 -0.129064 -0.315425  ...  0.767470 -0.561235  0.663768
#
# stock        PG         T       TRV       UTX        VZ       WMT       XOM
# stock
# AA    -0.162919  0.030825  0.405575  0.407474  0.728472  0.171045  0.685739
# AXP    0.670814  0.853905  0.589784  0.688131  0.239228  0.261840 -0.036042
#
# [2 rows x 30 columns]

# %%
sns.heatmap(corr_data)

# %%
type(corr_data[i:i+1])
# Out:
# pandas.core.frame.DataFrame

# %%
corr_data[i:i+1].unstack().sort_values(ascending=False)
# Out:
# stock  stock
# XOM    XOM      1.000000
# DD     XOM      0.863511
# DIS    XOM      0.803492
# CAT    XOM      0.803195
# CVX    XOM      0.802900
# GE     XOM      0.720823
# HD     XOM      0.716404
# AA     XOM      0.685739
# TRV    XOM      0.683718
# VZ     XOM      0.648415
# MMM    XOM      0.640352
# JPM    XOM      0.598958
# IBM    XOM      0.588332
# UTX    XOM      0.537364
# KO     XOM      0.503857
# BA     XOM      0.444624
# PFE    XOM      0.385485
# T      XOM      0.165279
# BAC    XOM      0.123588
# INTC   XOM      0.114054
# HPQ    XOM      0.075982
# AXP    XOM     -0.036042
# KRFT   XOM     -0.053104
# MCD    XOM     -0.104349
# MSFT   XOM     -0.116259
# CSCO   XOM     -0.120732
# WMT    XOM     -0.146847
# JNJ    XOM     -0.243448
# PG     XOM     -0.269751
# MRK    XOM     -0.308169
# dtype: float64

# %%
corr_data[i:i+1].unstack().sort_values(ascending=False)
# Out:
# pandas.core.series.Series

# %%
corr_data[i:i+1].unstack().sort_values(ascending=False)[[1]].idxmax()
# Out:
# ('DD', 'XOM')

# %%
max_corr = 0
stock1 = ''
stock2 = ''
for i in range(0,len(corr_data)):
    print (
        corr_data[i:i+1].unstack().sort_values(ascending=False)[[1]].idxmax()[1],
        corr_data[i:i+1].unstack().sort_values(ascending=False)[[1]].idxmax()[0],
        corr_data[i:i+1].unstack().sort_values(ascending=False)[[1]][0]
    )
    if max_corr < corr_data[i:i+1].unstack().sort_values(ascending=False)[[1]][0]:
        max_corr = corr_data[i:i+1].unstack().sort_values(ascending=False)[[1]][0]
        stock1 = corr_data[i:i+1].unstack().sort_values(ascending=False)[[1]].idxmax()[1]
        stock2 = corr_data[i:i+1].unstack().sort_values(ascending=False)[[1]].idxmax()[0]

print(f"[max corr]:{max_corr}")
print(f"[stock 1]:{stock1}")
print(f"[stock 2]:{stock2}")
# Out:
# AA DIS 0.7724697655620221
# AXP KRFT 0.8735103611554018
# BA UTX 0.9163379610743169
# BAC HPQ 0.9058167680009368
# CAT DD 0.902855810307895
# CSCO MSFT 0.9537216645891367
# CVX CAT 0.8894156562923723
# DD CAT 0.902855810307895
# DIS DD 0.8269258130241478
# GE HD 0.8582069310150247
# HD GE 0.8582069310150247
# HPQ BAC 0.9058167680009368
# IBM UTX 0.8975523835362522
# INTC BA 0.6910939563691996
# JNJ KRFT 0.8612879882611022
# JPM GE 0.8304508594360391
# KO T 0.8689952415835721
# KRFT MCD 0.9299213037922907
# MCD KRFT 0.9299213037922907
# MMM UTX 0.9136955626526879
# MRK JNJ 0.8440270438854452
# MSFT CSCO 0.9537216645891367
# PFE T 0.8065439446754142
# PG MRK 0.7497131367292446
# T KO 0.8689952415835721
# TRV MMM 0.8917262016156647
# UTX BA 0.9163379610743169
# VZ CAT 0.8903147891825165
# WMT PG 0.7237055485083297
# XOM DD 0.8635107559399795
# [max corr]:0.9537216645891367
# [stock 1]:CSCO
# [stock 2]:MSFT

# %%
pd_chp7_idx_uns[[stock1,stock2]].plot(subplots=True,grid=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12941aa50>,
# ...
#       dtype=object)

# %%
pd_chp7_idx_uns.rolling(window=5,center=True).mean().head(10)
# Out:
# stock          AA     AXP      BA     BAC      CAT    CSCO      CVX      DD  \
# date
# 1/14/2011     NaN     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1/21/2011     NaN     NaN     NaN     NaN      NaN     NaN      NaN     NaN
# 1/28/2011  16.336  45.444  70.500  14.424   95.942  20.506   93.524  50.556
# 1/7/2011   16.598  45.300  71.094  14.324   98.312  20.034   94.702  51.792
# 2/11/2011  16.776  44.806  71.218  14.314  100.162  19.618   96.366  52.936
# 2/18/2011  16.978  44.798  71.648  14.452  100.944  19.842   97.114  53.384
# 2/25/2011  16.900  44.782  72.100  14.478  102.202  19.238   98.862  54.012
# 2/4/2011   16.648  44.266  71.492  14.332  102.506  18.926  100.132  53.694
# 3/11/2011  16.610  44.278  71.552  14.050  103.152  18.612  101.744  53.318
# 3/18/2011  16.590  44.316  71.452  14.034  103.360  18.564  102.074  53.278
#
# stock         DIS      GE  ...     MRK    MSFT     PFE      PG       T  \
# date                       ...
# ...

# %%
log_ration_stock_close = np.log(pd_chp7_idx_uns/pd_chp7_idx_uns.shift(1))

max_vol_stock = log_ration_stock_close.std().idxmax()
min_vol_stock = log_ration_stock_close.std().idxmin()

print (f"{max_vol_stock},{min_vol_stock}")

log_ration_stock_close[max_vol_stock].plot()
log_ration_stock_close[min_vol_stock].plot()
plt.legend()
plt.grid(True)
# Out:
# CSCO,KO

# %%
log_ration_stock_close
# Out:
# stock            AA       AXP        BA       BAC       CAT      CSCO  \
# date
# 1/14/2011       NaN       NaN       NaN       NaN       NaN       NaN
# 1/21/2011 -0.011335 -0.005420  0.022717 -0.067823 -0.013493 -0.023373
# 1/28/2011  0.021304 -0.047639 -0.034777 -0.046687  0.031102  0.010084
# 1/7/2011   0.017819  0.011335  0.002164  0.046687 -0.020591  0.001909
# 2/11/2011  0.056244  0.052476  0.039010  0.035841  0.099540 -0.114569
# 2/18/2011 -0.005195 -0.026443  0.012399 -0.001355  0.022159  0.007989
# 2/25/2011 -0.035339 -0.044921 -0.010183 -0.038001 -0.037145 -0.011203
# 2/4/2011   0.027205  0.006640 -0.012806  0.006318 -0.023911  0.168003
# 3/11/2011 -0.066953  0.010443  0.003636  0.006278  0.004308 -0.205722
# 3/18/2011  0.004978 -0.002487 -0.036099 -0.023928  0.049161 -0.046175
# 3/25/2011  0.059053  0.031643  0.059551 -0.051143  0.037642  0.008135
# 3/4/2011  -0.030296 -0.041883 -0.021222  0.056825 -0.057056  0.062801
# ...
